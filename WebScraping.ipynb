# %% [markdown]
# # Webscraping with Jupter!
#
# ### Outline:
#
# - What is Webscrapping?
#
# - What is Jupyter?

# %% [markdown]
# ## Lets start with Webscraping, what is that?

# %% [markdown]
# ![title](imgs/diagram1.png)

# %% [markdown]
# - When you load a website, you are basicly requesting files from the server to be stored on your computer
# - Your browser will parse them and then give you a nice preaty page ;)
# - Loading up a site like wikipedia may give you something like this:
#
# ![title](imgs/wiki1.png)

# %% [markdown]
# - So what happened?
#     - We asked for some data, the server processed that request and gave us a page with all the data displayed for us to read.
#     - But what if we just want the data itself, not the page?

# %% [markdown]
# #### `Web scraping` is the process of loading web pages through scripts, parsing through the files, and extracting useful information

# %% [markdown]
# ## Why use Python and Jupyter?

# %% [markdown]
# - Python has a lot of amazing libraries for data processing and is quickly monopolizing the data sience field.
# - Python is also at the heart of machine learning libraries
# - Python is just data friendly in general, something we want for our web scraper

# %% [markdown]
# - Jupyter is the program you are using right now
# - It provided a very simple cell basted design that allows rapid conscruction of data pipelines
# - Jupyter saves data in the background so you dont have to worry about re-downloading data every time you run part of a script

# %% [markdown]
# # Lets try it out!

# %% [markdown]
# [Diamond back sallaryies](https://salaryguide.dbknews.com)
# ![Preview:](imgs/sal1.png)

# %% [markdown]
# - This site from the diamondback is able to show all the sallary information for all umd faculty!
# - Load up the page and go into the network tab, you can see the API requests they are making!
# - Lets get some data!

# %%
# API request modules
import requests
import pandas as pd
import time
from IPython.display import clear_output, display

# %%
# Request url from network information
request_url = "https://api.dbknews.com/salary/year/2019?search=&sortby=employee&order=desc&page=1"

# Send the request yourself to get the info
website_response = requests.get(url = request_url)

# Print response out
website_response
# Out:
# <Response [200]>

# %%
# Ask for the json data
response_data = website_response.json()
response_data
# Out:
# {'data': [{'Division': 'VP Research',
#    'Department': 'VPR-UM Ctr Applied Pol Studies (UMCAPS)',
#    'Title': 'Fac Res Asst',
#    'Employee': 'Zwiesler, Theodore W',
#    'Salary': '$49,989.28'},
#   {'Division': 'College of Computer, Math & Natural Sciences',
#    'Department': 'CMNS-Computer Science',
#    'Title': 'Prof',
#    'Employee': 'Zwicker, Matthias',
#    'Salary': '$231,199.32'},
#   {'Division': 'College of Computer, Math & Natural Sciences',
#    'Department': 'CMNS-Earth System Science Interdisciplinary Center',
#    'Title': 'Res Sci',
#    'Employee': 'Zwally, H Jay',
#    'Salary': '$83,232.00'},
#   {'Division': 'Robert H. Smith School of Business',
#    'Department': 'BMGT-Accounting',
#    'Title': 'Asst Prof',
#    'Employee': 'Zur, Emanuel',
#    'Salary': '$220,700.05'},
#   {'Division': 'VP Student Affairs',
#    'Department': 'VPSA-Transportation Services',
#    'Title': 'Driver, Bus',
#    'Employee': 'Zuniga, Ruben Oswaldo',
#    'Salary': '$35,702.19'},
#   {'Division': 'VP Student Affairs',
#    'Department': 'VPSA-Transportation Services',
#    'Title': 'Driver, Bus',
#    'Employee': 'Zuniga, Dina B',
#    'Salary': '$35,702.19'},
#   {'Division': 'College of Arts & Humanities',
#    'Department': 'ARHU-Linguistics',
#    'Title': 'Asst Res Sci',
#    'Employee': 'Zukowski, Andrea L.',
#    'Salary': '$66,911.62'},
#   {'Division': 'Universities at Shady Grove',
#    'Department': 'USG-Shady Grove Center',
#    'Title': 'Director',
#    'Employee': 'Zuknick, John',
#    'Salary': '$107,100.00'},
#   {'Division': 'College of Agriculture & Natural Resources',
#    'Department': 'AGNR-Environmental Science & Technology',
#    'Title': 'Lecturer',
#    'Employee': 'Zucchetto, James John',
#    'Salary': '$10,392.00'},
#   {'Division': 'Philip Merrill College of Journalism',
#    'Department': 'JOUR-Philip Merrill College of Journalism',
#    'Title': 'Lecturer',
#    'Employee': 'Zremski, Jerry',
#    'Salary': '$7,220.96'}],
#  'count': 10604}

# %%
# Get the data atribute, see what one entry looks like
request_raw_data = response_data['data']
request_raw_data[0]
# Out:
# {'Division': 'VP Research',
#  'Department': 'VPR-UM Ctr Applied Pol Studies (UMCAPS)',
#  'Title': 'Fac Res Asst',
#  'Employee': 'Zwiesler, Theodore W',
#  'Salary': '$49,989.28'}

# %%
# Pandas is an amazing package that takes in data like this and makes nice charts and tables!
data_frame = pd.DataFrame(request_raw_data, columns = ['Division', 'Department', 'Title', 'Employee', 'Salary']) 
data_frame
# Out:
#                                        Division  \
# 0                                   VP Research
# 1  College of Computer, Math & Natural Sciences
# 2  College of Computer, Math & Natural Sciences
# 3            Robert H. Smith School of Business
# 4                            VP Student Affairs
# 5                            VP Student Affairs
# 6                  College of Arts & Humanities
# 7                   Universities at Shady Grove
# 8    College of Agriculture & Natural Resources
# 9          Philip Merrill College of Journalism
#
#                                           Department         Title  \
# 0            VPR-UM Ctr Applied Pol Studies (UMCAPS)  Fac Res Asst
# 1                              CMNS-Computer Science          Prof
# 2  CMNS-Earth System Science Interdisciplinary Ce...       Res Sci
# 3                                    BMGT-Accounting     Asst Prof
# 4                       VPSA-Transportation Services   Driver, Bus
# 5                       VPSA-Transportation Services   Driver, Bus
# 6                                   ARHU-Linguistics  Asst Res Sci
# 7                             USG-Shady Grove Center      Director
# 8            AGNR-Environmental Science & Technology      Lecturer
# 9          JOUR-Philip Merrill College of Journalism      Lecturer
#
#                 Employee       Salary
# 0   Zwiesler, Theodore W   $49,989.28
# 1      Zwicker, Matthias  $231,199.32
# 2          Zwally, H Jay   $83,232.00
# 3           Zur, Emanuel  $220,700.05
# 4  Zuniga, Ruben Oswaldo   $35,702.19
# 5         Zuniga, Dina B   $35,702.19
# 6    Zukowski, Andrea L.   $66,911.62
# 7          Zuknick, John  $107,100.00
# 8  Zucchetto, James John   $10,392.00
# 9         Zremski, Jerry    $7,220.96

# %%
# But we dont want one response! We want them all !!
all_site_data = []

for i in range (1, 1062):
    
    url = 'https://api.dbknews.com/salary/year/2019?search=&sortby=employee&order=desc&page=' + str(i)
    data = requests.get(url = url).json()['data']
    all_site_data.extend(data)
    clear_output(wait=True)
    print('Request #', i, 'values', len(all_site_data),'/','1060')
# Out:
# Request # 1061 values 10604 / 10601

# %%
# So we just got over 10 thousand faculties worth of salary info!
# Lets store it in a table like before!
faculty_info = pd.DataFrame( all_site_data, columns = ['Division', 'Department', 'Title', 'Employee', 'Salary'])
faculty_info
# Out:
#                                                Division  \
# 0                                           VP Research
# 1          College of Computer, Math & Natural Sciences
# 2          College of Computer, Math & Natural Sciences
# 3                    Robert H. Smith School of Business
# 4                                    VP Student Affairs
# 5                                    VP Student Affairs
# 6                          College of Arts & Humanities
# 7                           Universities at Shady Grove
# 8            College of Agriculture & Natural Resources
# 9                  Philip Merrill College of Journalism
# 10         College of Computer, Math & Natural Sciences
# 11         College of Computer, Math & Natural Sciences
# 12                                Facilities Management
# 13         College of Computer, Math & Natural Sciences
# 14           College of Agriculture & Natural Resources
# 15                              School of Public Health
# 16                         College of Arts & Humanities
# 17                          Universities at Shady Grove
# 18                          VP Administration & Finance
# 19                                   VP Student Affairs
# 20                         College of Arts & Humanities
# 21                              Office of the President
# 22           College of Agriculture & Natural Resources
# 23                         College of Arts & Humanities
# 24         College of Computer, Math & Natural Sciences
# 25              College of Behavioral & Social Sciences
# 26           College of Agriculture & Natural Resources
# 27         College of Computer, Math & Natural Sciences
# 28         College of Computer, Math & Natural Sciences
# 29                                          VP Research
# ...                                                 ...
# 10574  School of Architecture, Planning, & Preservation
# 10575      College of Computer, Math & Natural Sciences
# 10576           College of Behavioral & Social Sciences
# 10577           College of Behavioral & Social Sciences
# 10578                                VP Student Affairs
# 10579                             Facilities Management
# 10580      College of Computer, Math & Natural Sciences
# 10581                Robert H. Smith School of Business
# 10582                             Facilities Management
# 10583      College of Computer, Math & Natural Sciences
# 10584      College of Computer, Math & Natural Sciences
# 10585              A. James Clark School of Engineering
# 10586                                VP Student Affairs
# 10587        College of Agriculture & Natural Resources
# 10588                                         Libraries
# 10589                Division of Information Technology
# 10590                           Office of the President
# 10591                  Sr VP Academic Affairs & Provost
# 10592        College of Agriculture & Natural Resources
# 10593                             Facilities Management
# 10594           College of Behavioral & Social Sciences
# 10595                                VP Student Affairs
# 10596                      College of Arts & Humanities
# 10597           College of Behavioral & Social Sciences
# 10598                             Facilities Management
# 10599                      College of Arts & Humanities
# 10600                       VP Administration & Finance
# 10601      College of Computer, Math & Natural Sciences
# 10602      College of Computer, Math & Natural Sciences
# 10603                  Sr VP Academic Affairs & Provost
#
#                                               Department                Title  \
# 0                VPR-UM Ctr Applied Pol Studies (UMCAPS)         Fac Res Asst
# 1                                  CMNS-Computer Science                 Prof
# 2      CMNS-Earth System Science Interdisciplinary Ce...              Res Sci
# 3                                        BMGT-Accounting            Asst Prof
# 4                           VPSA-Transportation Services          Driver, Bus
# 5                           VPSA-Transportation Services          Driver, Bus
# 6                                       ARHU-Linguistics         Asst Res Sci
# 7                                 USG-Shady Grove Center             Director
# 8                AGNR-Environmental Science & Technology             Lecturer
# 9              JOUR-Philip Merrill College of Journalism             Lecturer
# 10     CMNS-Earth System Science Interdisciplinary Ce...             Res Prof
# 11          CMNS-Institute for Advanced Computer Studies             Fac Spec
# 12                     VPAF-FM-AVP Facilities Management           Specialist
# 13                         CMNS-Chemistry & Biochemistry       Post-Doc Assoc
# 14                             AGNR-UME-Field Operations          Agent Assoc
# 15                                      SPHL-Kinesiology           Lect & Dir
# 16                                  ARHU-School of Music             Lecturer
# 17                                USG-Shady Grove Center          Coordinator
# 18               VPAF-Procurement and Strategic Sourcing          Coordinator
# 19                 VPSA-University Recreation & Wellness          Coordinator
# 20                                          ARHU-History                 Prof
# 21                        PRES-Intercollegiate Athletics           Asst Train
# 22               AGNR-AES-Agriculture Experiment Station          Sr Fac Spec
# 23                                  ARHU-School of Music                 Prof
# 24                                      CMNS-Mathematics           Assoc Prof
# 25                            BSOS-Government & Politics             Lecturer
# 26                      AGNR-Veterinary Medicine Program         Prof & Chair
# 27     CMNS-Inst for Research in Electronics & Applie...         Asst Res Sci
# 28                                          CMNS-Geology                 Prof
# 29                                       VPR-VP Research        Sr Accountant
# ...                                                  ...                  ...
# 10574  ARCH-School of Architecture, Planning, & Prese...             Lecturer
# 10575  CMNS-Inst for Research in Electronics & Applie...             Fac Spec
# 10576           BSOS-Joint Program in Survey Methodology                 Prof
# 10577                                     BSOS-Economics                 Prof
# 10578                      VPSA-University Health Center                Nurse
# 10579               VPAF-FM-O&M-Operations & Maintenance        HVAC Mech III
# 10580  CMNS-Inst for Research in Electronics & Applie...       Post-Doc Assoc
# 10581                     BMGT-Management & Organization             Lecturer
# 10582  VPAF-FM-B&LM-Building & Landscape Maintenance-...             Asst Mgr
# 10583                                    CMNS-Entomology             Fac Spec
# 10584  CMNS-Inst for Research in Electronics & Applie...   Visit Asst Res Sci
# 10585             ENGR-Electrical & Computer Engineering                 Prof
# 10586                               VPSA-Dining Services       Food Serv Sprv
# 10587            AGNR-Environmental Science & Technology         Admin Asst I
# 10588                                     LIBR-Libraries           Programmer
# 10589         DIT-EE-Enterprise Engineering & Operations  IT Senior  Engineer
# 10590                     PRES-Intercollegiate Athletics           Asst Coach
# 10591  SVPAAP-Institute for Bioscience & Biotechnolog...         Asst Res Sci
# 10592                          AGNR-UME-Field Operations         Admin Asst I
# 10593  VPAF-FM-B&LM-Building & Landscape Maintenance-...    Landscape Tech Sv
# 10594                                     BSOS-Economics      Senior Lecturer
# 10595                       VPSA-Transportation Services      Signage Tech II
# 10596  ARHU-School of Languages, Literatures, and Cul...           Assoc Prof
# 10597       BSOS-College of Behavioral & Social Sciences   Business Serv Spec
# 10598  VPAF-FM-B&LM-Building & Landscape Maintenance-...          Housekeeper
# 10599              ARHU-National Foreign Language Center         Fac Res Asst
# 10600                        VPAF-Finance Administration               Bursar
# 10601                              CMNS-Computer Science                 Prof
# 10602       CMNS-Institute for Advanced Computer Studies                 Prof
# 10603  SVPAAP-Teaching and Learning Transformation Ce...              Manager
#
#                               Employee       Salary
# 0                 Zwiesler, Theodore W   $49,989.28
# 1                    Zwicker, Matthias  $231,199.32
# 2                        Zwally, H Jay   $83,232.00
# 3                         Zur, Emanuel  $220,700.05
# 4                Zuniga, Ruben Oswaldo   $35,702.19
# 5                       Zuniga, Dina B   $35,702.19
# 6                  Zukowski, Andrea L.   $66,911.62
# 7                        Zuknick, John  $107,100.00
# 8                Zucchetto, James John   $10,392.00
# 9                       Zremski, Jerry    $7,220.96
# 10                        Zou, Xiaolei  $205,512.17
# 11                      Zotkina, Elena   $59,429.67
# 12                   Zook, Tiffany Ann   $59,160.00
# 13                      Zong, Guanghui   $46,920.00
# 14                        Zobel, Emily   $42,974.64
# 15                    Zimmerman, Jo B.   $81,600.00
# 16                Zimmerman, Daniel J.   $17,105.23
# 17                   Zimmer, Deborah F   $53,040.00
# 18                       Zimmer, Amy L   $76,683.60
# 19                Zilke, Joseph Edward   $52,668.86
# 20                  Zilfi, Madeline C.   $60,115.25
# 21               Ziemianski, Michael A   $48,961.02
# 22                 Ziegler, Gregory P.   $56,340.77
# 23                    Ziegler, Delores  $114,521.13
# 24         Zickert, Christian Krogager  $141,246.80
# 25                         Zic, Borjan   $11,161.92
# 26                       Zhu, Xiaoping  $226,667.00
# 27                          Zhu, Wenqi   $79,560.00
# 28                          Zhu, Wenlu  $160,122.67
# 29                     Zhu, Tina Geshu   $80,580.00
# ...                                ...          ...
# 10574           Abrams, Michael Carlos   $49,769.38
# 10575         Abrahams, John Henry III   $85,250.72
# 10576            Abraham, Katharine G.   $97,984.53
# 10577            Abraham, Katharine G.   $97,754.14
# 10578                Abraham, Anu Binu   $66,300.00
# 10579            Abimbola, Muisideen A   $55,844.34
# 10580       Abhyankar, Nandita Santosh   $70,923.66
# 10581           Aberman, Jonathan Moss   $46,694.84
# 10582                 Abell, Thomas C.   $76,583.39
# 10583                Abell, Kristopher   $48,425.52
# 10584                 Abel, Ian George   $83,640.00
# 10585                     Abed, Eyad H  $240,499.32
# 10586              Abebe, Selamawit T.   $33,418.57
# 10587                  Abebe, Elsabeth   $38,492.80
# 10588  Abdul Rasheed, Mohamed Mohideen   $75,181.91
# 10589             Abdulkareem, Saeed M  $130,000.00
# 10590              Abdul-Rahim, Aazaar   $99,999.80
# 10591              Abdul, Yunus Shukur  $122,400.00
# 10592               Abbott, Melanie J.   $43,791.29
# 10593                  Abbey, Penny D.   $54,972.45
# 10594                  Abbasi, Hossein   $78,989.25
# 10595                      Abban, Kofi   $39,942.28
# 10596                  Abasi, Ali Reza   $80,069.79
# 10597              Abarcar, Arri Jesus   $47,540.98
# 10598              Abarca, Francisco A   $25,663.20
# 10599                  Abadir, Miranda   $82,396.25
# 10600        Abadinsky, Alisa Michelle  $157,080.00
# 10601                  Abadi, Daniel J  $227,800.00
# 10602                  Abadi, Daniel J   $10,200.00
# 10603                Aarhus, William H   $77,265.00
#
# [10604 rows x 5 columns]

# %%
# If the above takes too long, try loading saved data :
faculty_info = pd.read_csv('faculty_data_output.csv')

# %%
# This is a lot of data, so lets save it just to make sure we have it in the future
faculty_info.to_csv('faculty_data_output.csv')

# %% [markdown]
# - What do we do now? lets try to get some faculty reviews to go allong with that data!
# ![rate](imgs/rate1.png)

# %% [markdown]
# ### Looking at the network info, this wont be as easy
# - Whereas the diamondback had a simple api that their site called and used to fill in data, this site sends us a html file with the data allready filled in
#
# ### Whats the solution?
# - Parse the html file!

# %%
# lets import some actuall scrapers now!
from bs4 import BeautifulSoup
import json

# %%
# Lets try with Kruskal first

target_url = 'https://www.ratemyprofessors.com/ShowRatings.jsp?tid=544717'
content = requests.get(target_url).content

# What does the site look like 
content

# OOF
# Out:
# b'\n\n\n\n\n\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n  <head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="google-site-verification" content="F8gUuqzRvOrAlhaGyP7aAuMs_Se8zK-98Ai2sNsIZEo"/>\n    <meta name="google-site-verification" content="hk1NnSbYuDC0Sppgbf7YIT-VxUiRbOVRdtqA4AmkGzM"/>\n    <meta name="google-site-verification" content="CKMC_IwvKoVbX1U8x1A9yzKABsSlop6qxfuDzwfV7Qs"/> <!--  relaunch qa -->\n    <meta name="google-site-verification" content="1D_3ZfAdMu4Tki8pFRj68YAqYot-paTOoDVzCTIJZZI"/> <!--  relaunch rmp -->\n    <meta name="google-signin-client_id" content="14147781149-i5ph5oqooelp3k0qfrb3jkk6vs4528ha.apps.googleusercontent.com">\n    \n      <script type="text/javascript">\n        \n      </script>\n    \n    <script src="https://use.fontawesome.com/fbed9f71e3.js"></script>\n    <link rel="stylesheet" href="/assets/application-f4e7b20d63f78aa5f304fd5d8c379f29.css"/>\n    <script src="/assets/libs/jquery-7f5fea5cae853e98f1d3f5d509216bd4.js" type="text/javascript" ></script>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0">\n    \n      <meta name="robots" content="all"/>\n    \n    <meta name="description" content="Rating and reviews for Professor Clyde Kruskal  from University of Maryland College Park, MD United States.">\n    <title>Clyde Kruskal at University of Maryland - RateMyProfessors.com</title>\n    <meta property="og:url" content="https://www.ratemyprofessors.com/ShowRatings.jsp?tid=544717">\n    <meta property="og:title" content="Clyde Kruskal at University of Maryland - RateMyProfessors.com">\n    <meta property="og:description" content="Check out the ratings and reviews for Clyde Kruskal  from University of Maryland in College Park, MD">\n    \n        <meta property="og:image" content="https://www.ratemyprofessors.com/assets/RMP_logo.png">\n    \n\n    <meta property="og:type" content="website">\n    \n    \n  <link rel="canonical" href="https://www.ratemyprofessors.com/ShowRatings.jsp?tid=544717" />\n    \n    <link rel="icon" href="/images/favicon-16.png" />\n    <link rel="icon" sizes="32\xc3\x9732" href="/images/favicon-32.png" />\n    <link rel="apple-touch-icon" href="/images/favicon-57.png" />\n    <link rel="apple-touch-icon" sizes="48\xc3\x9748" href="/images/favicon-48.png" />\n    <link rel="apple-touch-icon" sizes="72\xc3\x9772" href="/images/favicon-72.png" />\n    <link rel="apple-touch-icon" sizes="114\xc3\x97114" href="/images/favicon-114.png" />\n    <link rel="apple-touch-icon" sizes="152\xc3\x97152" href="/images/favicon-152.png" />\n    <link rel="apple-touch-icon-precomposed" href="/images/favicon-196.png"/>\n    <!--[if IE]><link rel="shortcut icon" href="/images/favicon-16.ico" /> <![endif]-->\n    <meta name="msapplication-TileColor" content="#ffffff"/>\n    <meta name="msapplication-TileImage" content="/images/favicon-16.png"/>\n    <script>\n      (function() {\n        var _fbq = window._fbq || (window._fbq = []);\n        if (!_fbq.loaded) {\n          var fbds = document.createElement(\'script\');\n          fbds.async = true;\n          fbds.src = \'//connect.facebook.net/en_US/fbds.js\';\n          var s = document.getElementsByTagName(\'script\')[0];\n          s.parentNode.insertBefore(fbds, s);\n          _fbq.loaded = true;\n        }\n        _fbq.push([\'addPixelId\', \'331289063738687\']);\n      })();\n      window._fbq = window._fbq || [];\n      window._fbq.push([\'track\', \'PixelInitialized\', {}]);\n    </script>\n    <noscript><img height="1" width="1" alt="" style="display:none" src="https://www.facebook.com/tr?id=331289063738687&ev=Pix ...

# %%
# But beutiful soup can handle it!
soup = BeautifulSoup(content, 'html5lib')

# %%
# AND THERE WE HAVE IT!
# We just read in the page and searched for the specific number we needed!
element = soup.find('div', attrs = {'class':'grade'})
element.text
# Out:
# '2.7'

# %%
# Lets get some more!
elements = soup.findAll('div', attrs = {'class':'grade'})

# Overall quality | Would take again | Level of difficulty
[e.text.strip() for e in elements]
# Out:
# ['2.7', '21%', '4.0']

# %%
# Now lets use some function magic to get this result for any faculty we want!

def get_query( name ):
    # you can disect this function if you want, but just assume it works correctly and move on
    # its basicly just getting an api path and doing some parsing
    name = (name.lower() + '+university of maryland').replace(' ','+')
    base_url = 'https://solr-aws-elb-production.ratemyprofessors.com//solr/rmp/select/?solrformat=true&rows=20&wt=json&json.wrf=noCB&callback=noCB&q=' + name + '&defType=edismax&qf=teacherfirstname_t%5E2000+teacherlastname_t%5E2000+teacherfullname_t%5E2000+autosuggest&bf=pow(total_number_of_ratings_i%2C1.7)&sort=score+desc&siteName=rmp&group=on&group.field=content_type_s&group.limit=20'

    data = requests.get(url = base_url)
    raw_json_data =  json.loads(data.content.decode('utf-8')[5:-1])['grouped']['content_type_s']['groups'][0]['doclist']['docs'][0]
    return (    raw_json_data['averageratingscore_rf'], 
                raw_json_data['averagehelpfulscore_rf'], 
                raw_json_data['averageeasyscore_rf'], 
                raw_json_data['schoolname_s'],
           )

# %%
    
# Gets query data directly!
rating, helpful, easy, school = get_query('Kruskal')

print('Faculty from', school, '. Rating of', rating, '. Helpfulness of', helpful, '. Difficulty of', easy)
# Out:
# Faculty from University of Maryland . Rating of 2.7 . Helpfulness of 2.6 . Difficulty of 4.0

# %% [markdown]
# ## So what have we got now?
#
# - All the professors and their pay
# - Ability to rate each ( most ) of them
#
# ## What now?
#
# - Give each teacher a value score! ( I do not endorse actually thinking of any faculty in this way, but lets just try if for fun )

# %%
# Lets pull it together!
import math

# %%
# Searching by name, get results
names = faculty_info['Employee'].values
def search( name ):
    
    name = name.lower()
    options = [ a for a in names if name in a.lower()]
    
    print('Did search for', name, 'Results :', options)
    if len(options) == 0: return (False, None)
    
    print('Taking first entry info:')
    
    return (True, faculty_info.loc[faculty_info['Employee'] == options[0]])

found, data = search('Kruskal')
data
# Out:
# Did search for kruskal Results : ['Kruskal, Clyde P.']
# Taking first entry info:
#                                           Division             Department  \
# 5490  College of Computer, Math & Natural Sciences  CMNS-Computer Science
#
#            Title           Employee      Salary
# 5490  Assoc Prof  Kruskal, Clyde P.  $84,033.89

# %%
# Add in API Calls and print some information

def unified_info( name ):
    
    found, search_data = search( name )
    if not found: return
    
    rating, helpful, easy, school = get_query(name)
    
    # Salary saved as a string, converting it over to float
    money = float( search_data['Salary'].values[0][1:].replace(',',''))
    score = round(  money  / rating,2)
    
    print('-----')
    print(search_data['Employee'].values[0], 'makes', search_data['Salary'].values[0], 'dollars per year')
    print(search_data['Employee'].values[0], 'has a rating of', rating)
    print('That is a score of $', score, 'dollars / rating point')

# %%
unified_info('kruskal')
# Out:
# Did search for kruskal Results : ['Kruskal, Clyde P.']
# Taking first entry info:
# -----
# Kruskal, Clyde P. makes $84,033.89 dollars per year
# Kruskal, Clyde P. has a rating of 2.7
# That is a score of $ 31123.66 dollars / rating point
